# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

from scipy.spatial import minkowski_distance
from sklearn.preprocessing import StandardScaler

from utitilies.data_visualizers import view_clusters_3d

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Preprocessing data

# %%
df = pd.read_csv('./E-commerce.csv')
df
# Out:
#         ID  n_clicks  n_visits  amount_spent  amount_discount  \
# 0     2085       643       142    300.000000       228.432503
# 1      742       527        95    743.832508        60.882831
# 2      750       367        49    305.668886        72.961801
# 3     1224       466        30    291.191193       101.903170
# 4     2210       715       169    703.136878       506.416735
# ...    ...       ...       ...           ...              ...
# 2495   269       231       165   3328.628199       148.313702
# 2496   399       241        26   1985.954206         5.129457
# 2497   945       561        85    936.915959       146.637412
# 2498   771       347        61    404.905296       119.284162
# 2499  1999       823       160   1433.677219      1138.219484
#
#       days_since_registration  profile_information
# 0                         132                  411
# 1                          86                  184
# 2                         334                  329
# ...

# %% [markdown]
# * ### drop uneccessary columns like ID column
# * ### will be later visualized in 3d so keep only 3 variables/features like n_clicks, n_visits, amount_spent
# * ### normalize data

# %%
X = df
# scaler = StandardScaler()
# X = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
# X

# %%
X.drop(columns=['ID'], inplace=True)
# X.drop(columns=['ID', 'amount_discount', 'days_since_registration', 'profile_information'], inplace=True)
# X

# %% [markdown]
# # Exploratory data analysis

# %%
view_clusters_3d(X, ['n_visits', 'amount_spent', 'amount_discount'])

# %%
sb.set_palette('magma')
sb.pairplot(X)
plt.show()
